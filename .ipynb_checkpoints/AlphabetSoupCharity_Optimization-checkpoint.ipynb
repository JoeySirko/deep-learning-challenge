# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import and read the charity_data.csv
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'
application_df = application_df.drop(["EIN", "NAME"], axis=1)

# %%
# Determine the number of unique values in each column
print(application_df.nunique())
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < 300].index)

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")
    
# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 300].index)

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values
X = application_df.drop(["IS_SUCCESSFUL"], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=30)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()


# Fit the StandardScaler
X_scaler = scaler.fit(X_train)


# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer
neural_model = tf.keras.models.Sequential()

# First hidden layer with more units and dropout
neural_model.add(tf.keras.layers.Dense(units=64, activation='relu', input_dim=X_train_scaled.shape[1]))
neural_model.add(tf.keras.layers.Dropout(0.5))

# Second hidden layer with more units and dropout
neural_model.add(tf.keras.layers.Dense(units=128, activation='relu'))
neural_model.add(tf.keras.layers.Dropout(0.5))

# SECRET HIDDEN LAYER
# For Whoever Brave Enough To Try I Couldn't Go Any Higher ( $ DISCLAMIER $ I DO NOT RECOMMEND)
# neural_model.add(tf.keras.layers.Dense(units=4194304, activation='relu', input_dim=X_train_scaled.shape[1]))


# Output layer
neural_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the model
neural_model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
# Train the model
fit_model = neural_model.fit(X_train_scaled, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 627us/step - loss: 0.7094 - accuracy: 0.5917
# Epoch 2/100
# 804/804 [==============================] - 0s 584us/step - loss: 0.6506 - accuracy: 0.6661
# Epoch 3/100
# 804/804 [==============================] - 0s 584us/step - loss: 0.6276 - accuracy: 0.6882
# Epoch 4/100
# 804/804 [==============================] - 0s 585us/step - loss: 0.6140 - accuracy: 0.6999
# Epoch 5/100
# 804/804 [==============================] - 0s 576us/step - loss: 0.6032 - accuracy: 0.7086
# Epoch 6/100
# 804/804 [==============================] - 0s 575us/step - loss: 0.6005 - accuracy: 0.7088
# Epoch 7/100
# 804/804 [==============================] - 0s 568us/step - loss: 0.5945 - accuracy: 0.7110
# Epoch 8/100
# 804/804 [==============================] - 0s 577us/step - loss: 0.5944 - accuracy: 0.7141
# Epoch 9/100
# 804/804 [==============================] - 0s 574us/step - loss: 0.5869 - accuracy: 0.7182
# Epoch 10/100
# 804/804 [==============================] - 0s 592us/step - loss: 0.5841 - accuracy: 0.7196
# Epoch 11/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5825 - accuracy: 0.7215
# Epoch 12/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5807 - accuracy: 0.7215
# Epoch 13/100
# 804/804 [==============================] - 0s 602us/step - loss: 0.5777 - accuracy: 0.7216
# Epoch 14/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5786 - accuracy: 0.7231
# Epoch 15/100
# 804/804 [==============================] - 0s 607us/step - loss: 0.5740 - accuracy: 0.7229
# Epoch 16/100
# 804/804 [==============================] - 0s 602us/step - loss: 0.5732 - accuracy: 0.7248
# Epoch 17/100
# 804/804 [==============================] - 0s 575us/step - loss: 0.5711 - accuracy: 0.7251
# Epoch 18/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5725 - accuracy: 0.7245
# Epoch 19/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5700 - accuracy: 0.7248
# Epoch 20/100
# 804/804 [==============================] - 0s 618us/step - loss: 0.5715 - accuracy: 0.7258
# Epoch 21/100
# 804/804 [==============================] - 0s 610us/step - loss: 0.5680 - accuracy: 0.7259
# Epoch 22/100
# 804/804 [==============================] - 0s 608us/step - loss: 0.5681 - accuracy: 0.7256
# Epoch 23/100
# 804/804 [==============================] - 0s 601us/step - loss: 0.5682 - accuracy: 0.7253
# Epoch 24/100
# 804/804 [==============================] - 0s 608us/step - loss: 0.5658 - accuracy: 0.7286
# Epoch 25/100
# 804/804 [==============================] - 1s 623us/step - loss: 0.5684 - accuracy: 0.7273
# Epoch 26/100
# 804/804 [==============================] - 0s 608us/step - loss: 0.5649 - accuracy: 0.7280
# Epoch 27/100
# 804/804 [==============================] - 0s 580us/step - loss: 0.5633 - accuracy: 0.7283
# Epoch 28/100
# 804/804 [==============================] - 0s 598us/step - loss: 0.5652 - accuracy: 0.7253
# Epoch 29/100
# 804/804 [==============================] - 0s 577us/step - loss: 0.5643 - accuracy: 0.7271
# Epoch 30/100
# 804/804 [==============================] - 0s 597us/step - loss: 0.5630 - accuracy: 0.7280
# Epoch 31/100
# 804/804 [==============================] - 0s 585us/step - loss: 0.5636 - accuracy: 0.7284
# Epoch 32/100
# 804/804 [==============================] - 0s 600us/step - loss: 0.5610 - accuracy: 0.7290
# Epoch 33/100
# 804/804 [==============================] - 0s 602us/step - loss: 0.5623 - accuracy: 0.7303
# Epoch 34/100
# 804/804 [==============================] - 0s 606us/step - loss: 0.5633 - accuracy: 0.7294
# Epoch 35/100
# 804/804 [==============================] - 0s 601us/step - loss: 0.5611 - accuracy: 0.7299
# Epoch 36/100
# 804/804 [==============================] - 0s 570us/step - loss: 0.5609 - accuracy: 0.7303
# Epoch 37/100
# 804/804 [==============================] - 0s 589us/step - loss: 0.5606 - accuracy: 0.7302
# Epoch 38/100
# 804/804 [==============================] - 0s 576us/step - loss: 0.5588 - accuracy: 0.7309
# Epoch 39/100
# 804/804 [==============================] - 0s 598us/step - loss: 0.5609 - accuracy: 0.7298
# Epoch 40/100
# 804/804 [==============================] - 0s 575us/step - loss: 0.5588 - accuracy: 0.7310
# Epoch 41/100
# 804/804 [==============================] - 1s 625us/step - loss: 0.5595 - accuracy: 0.7306
# Epoch 42/100
# 804/804 [==============================] - 0s 572us/step - loss: 0.5589 - accuracy: 0.7294
# Epoch 43/100
# 804/804 [==============================] - 0s 587us/step - loss: 0.5577 - accuracy: 0.7319
# Epoch 44/100
# 804/804 [==============================] - 0s 572us/step - loss: 0.5599 - accuracy: 0.7308
# Epoch 45/100
# 804/804 [==============================] - 0s 583us/step - loss: 0.5581 - accuracy: 0.7297
# Epoch 46/100
# 804/804 [==============================] - 0s 587us/step - loss: 0.5586 - accuracy: 0.7304
# Epoch 47/100
# 804/804 [==============================] - 0s 606us/step - loss: 0.5582 - accuracy: 0.7306
# Epoch 48/100
# 804/804 [==============================] - 0s 606us/step - loss: 0.5584 - accuracy: 0.7307
# Epoch 49/100
# 804/804 [==============================] - 0s 607us/step - loss: 0.5564 - accuracy: 0.7300
# Epoch 50/100
# 804/804 [==============================] - 0s 597us/step - loss: 0.5564 - accuracy: 0.7314
# Epoch 51/100
# 804/804 [==============================] - 0s 604us/step - loss: 0.5585 - accuracy: 0.7294
# Epoch 52/100
# 804/804 [==============================] - 0s 594us/step - loss: 0.5575 - accuracy: 0.7327
# Epoch 53/100
# 804/804 [==============================] - 0s 591us/step - loss: 0.5569 - accuracy: 0.7321
# Epoch 54/100
# 804/804 [==============================] - 0s 614us/step - loss: 0.5543 - accuracy: 0.7309
# Epoch 55/100
# 804/804 [==============================] - 1s 681us/step - loss: 0.5559 - accuracy: 0.7328
# Epoch 56/100
# 804/804 [==============================] - 1s 637us/step - loss: 0.5559 - accuracy: 0.7314
# Epoch 57/100
# 804/804 [==============================] - 1s 622us/step - loss: 0.5559 - accuracy: 0.7315
# Epoch 58/100
# 804/804 [==============================] - 0s 616us/step - loss: 0.5560 - accuracy: 0.7314
# Epoch 59/100
# 804/804 [==============================] - 1s 641us/step - loss: 0.5565 - accuracy: 0.7306
# Epoch 60/100
# 804/804 [==============================] - 0s 612us/step - loss: 0.5551 - accuracy: 0.7330
# Epoch 61/100
# 804/804 [==============================] - 0s 591us/step - loss: 0.5548 - accuracy: 0.7312
# Epoch 62/100
# 804/804 [==============================] - 0s 584us/step - loss: 0.5564 - accuracy: 0.7322
# Epoch 63/100
# 804/804 [==============================] - 0s 582us/step - loss: 0.5543 - accuracy: 0.7326
# Epoch 64/100
# 804/804 [==============================] - 0s 590us/step - loss: 0.5552 - accuracy: 0.7320
# Epoch 65/100
# 804/804 [==============================] - 0s 579us/step - loss: 0.5539 - accuracy: 0.7326
# Epoch 66/100
# 804/804 [==============================] - 0s 594us/step - loss: 0.5549 - accuracy: 0.7311
# Epoch 67/100
# 804/804 [==============================] - 0s 572us/step - loss: 0.5534 - accuracy: 0.7324
# Epoch 68/100
# 804/804 [==============================] - 0s 597us/step - loss: 0.5530 - accuracy: 0.7327
# Epoch 69/100
# 804/804 [==============================] - 0s 579us/step - loss: 0.5536 - accuracy: 0.7340
# Epoch 70/100
# 804/804 [==============================] - 0s 584us/step - loss: 0.5549 - accuracy: 0.7322
# Epoch 71/100
# 804/804 [==============================] - 0s 573us/step - loss: 0.5532 - accuracy: 0.7341
# Epoch 72/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5534 - accuracy: 0.7319
# Epoch 73/100
# 804/804 [==============================] - 0s 578us/step - loss: 0.5540 - accuracy: 0.7325
# Epoch 74/100
# 804/804 [==============================] - 0s 602us/step - loss: 0.5521 - accuracy: 0.7329
# Epoch 75/100
# 804/804 [==============================] - 0s 584us/step - loss: 0.5524 - accuracy: 0.7314
# Epoch 76/100
# 804/804 [==============================] - 0s 585us/step - loss: 0.5521 - accuracy: 0.7338
# Epoch 77/100
# 804/804 [==============================] - 1s 623us/step - loss: 0.5534 - accuracy: 0.7320
# Epoch 78/100
# 804/804 [==============================] - 0s 587us/step - loss: 0.5523 - accuracy: 0.7333
# Epoch 79/100
# 804/804 [==============================] - 0s 581us/step - loss: 0.5531 - accuracy: 0.7326
# Epoch 80/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5542 - accuracy: 0.7304
# Epoch 81/100
# 804/804 [==============================] - 0s 588us/step - loss: 0.5533 - accuracy: 0.7308
# Epoch 82/100
# 804/804 [==============================] - 0s 578us/step - loss: 0.5502 - accuracy: 0.7330
# Epoch 83/100
# 804/804 [==============================] - 0s 587us/step - loss: 0.5522 - accuracy: 0.7332
# Epoch 84/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5514 - accuracy: 0.7337
# Epoch 85/100
# 804/804 [==============================] - 0s 589us/step - loss: 0.5537 - accuracy: 0.7325
# Epoch 86/100
# 804/804 [==============================] - 0s 574us/step - loss: 0.5513 - accuracy: 0.7334
# Epoch 87/100
# 804/804 [==============================] - 0s 590us/step - loss: 0.5524 - accuracy: 0.7331
# Epoch 88/100
# 804/804 [==============================] - 0s 575us/step - loss: 0.5505 - accuracy: 0.7331
# Epoch 89/100
# 804/804 [==============================] - 0s 589us/step - loss: 0.5504 - accuracy: 0.7321
# Epoch 90/100
# 804/804 [==============================] - 0s 572us/step - loss: 0.5528 - accuracy: 0.7328
# Epoch 91/100
# 804/804 [==============================] - 0s 590us/step - loss: 0.5521 - accuracy: 0.7324
# Epoch 92/100
# 804/804 [==============================] - 0s 574us/step - loss: 0.5522 - accuracy: 0.7315
# Epoch 93/100
# 804/804 [==============================] - 0s 586us/step - loss: 0.5512 - accuracy: 0.7325
# Epoch 94/100
# 804/804 [==============================] - 0s 581us/step - loss: 0.5498 - accuracy: 0.7345
# Epoch 95/100
# 804/804 [==============================] - 0s 590us/step - loss: 0.5523 - accuracy: 0.7335
# Epoch 96/100
# 804/804 [==============================] - 0s 585us/step - loss: 0.5512 - accuracy: 0.7349
# Epoch 97/100
# 804/804 [==============================] - 0s 582us/step - loss: 0.5509 - accuracy: 0.7338
# Epoch 98/100
# 804/804 [==============================] - 0s 583us/step - loss: 0.5522 - accuracy: 0.7336
# Epoch 99/100
# 804/804 [==============================] - 0s 616us/step - loss: 0.5506 - accuracy: 0.7331
# Epoch 100/100
# 804/804 [==============================] - 0s 585us/step - loss: 0.5499 - accuracy: 0.7339

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = neural_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# I Can't get past 72.48% I tried
# Out:
# 268/268 - 0s - loss: 0.5622 - accuracy: 0.7249 - 152ms/epoch - 565us/step
# Loss: 0.5622167587280273, Accuracy: 0.7248979806900024

# %%
# Export our model to HDF5 file
# commented out to prevent saving
neural_model.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# C:\Users\Joey\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
